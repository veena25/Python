# %%
file_handle = open("example.txt") #The file location is same as this notebook. So we do not need to provide full path.
print(file_handle.read()) #read and print file using file_handle object which saved the
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},
#    "outputs": [
#     {
#      "ename": "FileNotFoundError",
#      "evalue": "[Errno 2] No such file or directory: 'example.txt'",
#      "output_type": "error",
#      "traceback": [
#       "\u001b---------------------------------------------------------------------------\u001b",
#       "\u001bFileNotFoundError\u001b                         Traceback (most recent call last)",
#       "Input \u001bIn [3]\u001b, in \u001b<cell line: 1>\u001b()\u001b\n\u001b----> 1\u001b file_handle \u001b=\u001b \u001bopen\u001b\u001b(\u001b\u001b\"\u001b\u001bexample.txt\u001b\u001b\"\u001b\u001b)\u001b \u001b#The file location is same as this notebook. So we do not need to provide full path.\u001b\n\u001b      2\u001b \u001bprint\u001b(file_handle\u001b.\u001bread())\n",
#       "\u001bFileNotFoundError\u001b: [Errno 2] No such file or directory: 'example.txt'"
#      ]
#     }
#    ],
# ...

# %%
file_handle.seek(0) #Set file read pointer to 0 location.
print(file_handle.read(33)) #The first line is comprised of 33 characters.

# %%
print(file_handle.readline()) #Readline. As we didn't reset file read pointer, it will start reading ahead of previous loc.
file_handle.close()

# %%
#Example: Read coma-separated numeric data from a file, convert it to list of numbers.

#Open and read complete data file. Save data to string variable
file_handle = open("data.txt") 
data = file_handle.read()
print(data)
file_handle.close()

#Seperate the data based on comma in a list
my_list = data.split(",")
print(my_list)

#Convert string elements in numerics
for element in range(len(my_list)):
    my_list[element] = int(my_list[element])

print(my_list)

# %%
file_handle = open("example.txt", "a") #set the append mode to add more text to the file without overwriting
file_handle.write("This is line 4 of the text file") #Write to the file
file_handle.close() #close the file
